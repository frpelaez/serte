# %%
from timeseries import TimeSeries
import pandas as pd

# %%
df = pd.read_spss("./data/total_acciones.sav")
df.head()
# Out:
# <marimo-ui-element object-id='kxyz-0' random-id='1d7585ad-f2c5-c667-acbc-7fae08b5e72d'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;Total_acciones&#92;&quot;:1737130.0,&#92;&quot;YEAR_&#92;&quot;:1991.0,&#92;&quot;MONTH_&#92;&quot;:1.0,&#92;&quot;DATE_&#92;&quot;:&#92;&quot;JAN 1991&#92;&quot;},{&#92;&quot;Total_acciones&#92;&quot;:2714250.0,&#92;&quot;YEAR_&#92;&quot;:1991.0,&#92;&quot;MONTH_&#92;&quot;:2.0,&#92;&quot;DATE_&#92;&quot;:&#92;&quot;FEB 1991&#92;&quot;},{&#92;&quot;Total_acciones&#92;&quot;:2940488.0,&#92;&quot;YEAR_&#92;&quot;:1991.0,&#92;&quot;MONTH_&#92;&quot;:3.0,&#92;&quot;DATE_&#92;&quot;:&#92;&quot;MAR 1991&#92;&quot;},{&#92;&quot;Total_acciones&#92;&quot;:2349157.0,&#92;&quot;YEAR_&#92;&quot;:1991.0,&#92;&quot;MONTH_&#92;&quot;:4.0,&#92;&quot;DATE_&#92;&quot;:&#92;&quot;APR 1991&#92;&quot;},{&#92;&quot;Total_acciones&#92;&quot;:2553893.0,&#92;&quot;YEAR_&#92;&quot;:1991.0,&#92;&quot;MONTH_&#92;&quot;:5.0,&#92;&quot;DATE_&#92;&quot;:&#92;&quot;MAY 1991&#92;&quot;}]&quot;' data-total-rows='5' data-total-columns='4' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='30' data-field-types='[[&quot;Total_acciones&quot;,[&quot;number&quot;,&quot;float64&quot;]],[&quot;YEAR_&quot;,[&quot;number&quot;,&quot;float64&quot;]],[&quot;MONTH_&quot;,[&quot;number&quot;,&quot;float64&quot;]],[&quot;DATE_&quot;,[&quot;string&quot;,&quot;object&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
acciones = (
    TimeSeries.from_spss("./data/total_acciones.sav", "Total_acciones", "DATE_")
    .with_name("Acciones")
    .with_index_name("Tiempo")
)
acciones.plot()
# Out:
# C:\Users\franp\Python\TECI\srs-tmp\serte\timeseries.py:85: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.index = pd.to_datetime(df.index)

# %%
acciones_log = acciones.log()
acciones_log.plot()

# %%
acciones_log.nsdiffs(period=12)
# Out:
# WARN: to use 'ocsb' or 'ch' tests you need to install 'pmdarima'
# 'seas' (seasonal force) will be used instead

# %%
acciones_log_diff = acciones_log.diff()
acciones_log_diff.plot()

# %%
acciones_log_diff.plot_correlograms(lags=48)

# %% [markdown]
# p = 2, P = 1
#
# d = 1, D = 0
#
# q = 1, Q = 2

# %%
import marimo as mo

# %%
from timeseries import TimeSeries

# %%
casas = (
    TimeSeries.from_spss("./data/casas.sav", "casas", "DATE_")
    .with_name("Casas")
    .with_index_name("Tiempo")
)
casas.plot()
# Out:
# C:\Users\franp\Python\TECI\srs-tmp\serte\timeseries.py:85: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.index = pd.to_datetime(df.index)

# %%
decomp = casas.decompose(period=12)
decomp.plot()

# %%
casas.plot_correlograms()

# %%
casas_bxcx, lmb = casas.box_cox()
print("lambda:", lmb)
casas_bxcx.plot()
# Out:
# lambda: 0.7305243918787679

# %%
casas_bxcx.nsdiffs(period=12)
# Out:
# WARN: to use 'ocsb' or 'ch' tests you need to install 'pmdarima'
# 'seas' (seasonal force) will be used instead

# %%
casas_bxcx_sdiff = casas_bxcx.diff(order=0, seasonal_lag=12, seasonal_order=1)
casas_bxcx_sdiff.plot()

# %%
casas_bxcx_sdiff.plot_correlograms()

# %% [markdown]
# Tenemos que la gráfica de FAS decae lentamente, mientras que en la del FAP tenemos un corte abrupto después del lag 1. Con la diferenciación que habíamos hecho, tenemos d = 1 y p = 1.

# %%
import marimo as mo

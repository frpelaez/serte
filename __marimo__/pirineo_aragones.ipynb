# %%
from timeseries import TimeSeries
import pandas as pd

# %%
df = pd.read_csv("./data/pirineo-aragones.csv")
df.head()
# Out:
# <marimo-ui-element object-id='pRSb-0' random-id='daf22b61-fe64-de9e-ef0c-22b66422f87a'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;PERIODO&#92;&quot;:&#92;&quot;2025M11&#92;&quot;,&#92;&quot;VALOR&#92;&quot;:5.528,&#92;&quot;TIPO DATO&#92;&quot;:&#92;&quot;Provisional&#92;&quot;,&#92;&quot;NOTA&#92;&quot;:null},{&#92;&quot;PERIODO&#92;&quot;:&#92;&quot;2025M10&#92;&quot;,&#92;&quot;VALOR&#92;&quot;:6.832,&#92;&quot;TIPO DATO&#92;&quot;:&#92;&quot;Provisional&#92;&quot;,&#92;&quot;NOTA&#92;&quot;:null},{&#92;&quot;PERIODO&#92;&quot;:&#92;&quot;2025M09&#92;&quot;,&#92;&quot;VALOR&#92;&quot;:6.76,&#92;&quot;TIPO DATO&#92;&quot;:&#92;&quot;Provisional&#92;&quot;,&#92;&quot;NOTA&#92;&quot;:null},{&#92;&quot;PERIODO&#92;&quot;:&#92;&quot;2025M08&#92;&quot;,&#92;&quot;VALOR&#92;&quot;:13.919,&#92;&quot;TIPO DATO&#92;&quot;:&#92;&quot;Provisional&#92;&quot;,&#92;&quot;NOTA&#92;&quot;:null},{&#92;&quot;PERIODO&#92;&quot;:&#92;&quot;2025M07&#92;&quot;,&#92;&quot;VALOR&#92;&quot;:10.091,&#92;&quot;TIPO DATO&#92;&quot;:&#92;&quot;Provisional&#92;&quot;,&#92;&quot;NOTA&#92;&quot;:null}]&quot;' data-total-rows='5' data-total-columns='4' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='30' data-field-types='[[&quot;PERIODO&quot;,[&quot;string&quot;,&quot;object&quot;]],[&quot;VALOR&quot;,[&quot;number&quot;,&quot;float64&quot;]],[&quot;TIPO DATO&quot;,[&quot;string&quot;,&quot;object&quot;]],[&quot;NOTA&quot;,[&quot;number&quot;,&quot;float64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
pirineo = (
    TimeSeries.from_csv("./data/pirineo-aragones.csv", "VALOR", "PERIODO")
    .with_name("Viajeros")
    .with_index_name("Tiempo")
)
pirineo.head()
# Out:
# C:\Users\franp\Python\TECI\srs-tmp\serte\timeseries.py:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(

# %%
pirineo.plot()
